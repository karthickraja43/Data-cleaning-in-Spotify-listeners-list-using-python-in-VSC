# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import matplotlib .pyplot as plt

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.1 MB 4.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 4.6 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.3 MB/s  0:00:01
# ...

# %%
import pandas as pd

# %%
# %pip instal lib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
data = pd.read_csv("songs.csv")

# %%
data.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# ...

# %%
data.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# ...

# %%
data["listening_time"]
# Out:
# 0      26
# 1     141
# 2     199
# 3      36
# 4     250
# 5     219
# 6     289
# 7     210
# 8      50
# 9     278
# 10     86
# 11    113
# 12     24
# 13     45
# 14    114
# 15    230
# 16    181
# 17    120
# 18    160
# Name: listening_time, dtype: int64

# %%
data.drop_duplicates
data
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# 12       13  Female   37      IN            Family              24
# ...

# %%
data.drop(columns="is_churned")
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# 12       13  Female   37      IN            Family              24
# ...

# %%
data["gender"] = data["gender"].str.strip("...")
data
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# 12       13  Female   37      IN            Family              24
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# ...

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# ...

# %%
data.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['gender']=range(1,len(data)+1)

# %%
data.fillna(0)
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1       1   54      CA              Free              26
# 1         2       2   33      DE            Family             141
# 2         3       3   38      AU           Premium             199
# 3         4       4   22      CA           Student              36
# 4         5       5   29      US            Family             250
# 5         6       6   17      AU              Free             219
# 6         7       7   39      UK           Premium             289
# 7         8       8   41      UK              Free             210
# 8         9       9   55      DE           Student              50
# 9        10      10   44      DE              Free             278
# 10       11      11   33      DE              Free              86
# 11       12      12   24      CA              Free             113
# 12       13      13   37      IN            Family              24
# ...

# %%
data['age'] = data['age'].astype(int)

# %%
data['age'] = data['age'].astype('Int64')

# %%
data['age'].astype('Int64')
# Out:
# 0     54
# 1     33
# 2     38
# 3     22
# 4     29
# 5     17
# 6     39
# 7     41
# 8     55
# 9     44
# 10    33
# 11    24
# 12    37
# 13    53
# 14    37
# 15    25
# 16    36
# 17    58
# 18    34
# Name: age, dtype: Int64

# %%
data
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1       1   54      CA              Free              26
# 1         2       2   33      DE            Family             141
# 2         3       3   38      AU           Premium             199
# 3         4       4   22      CA           Student              36
# 4         5       5   29      US            Family             250
# 5         6       6   17      AU              Free             219
# 6         7       7   39      UK           Premium             289
# 7         8       8   41      UK              Free             210
# 8         9       9   55      DE           Student              50
# 9        10      10   44      DE              Free             278
# 10       11      11   33      DE              Free              86
# 11       12      12   24      CA              Free             113
# 12       13      13   37      IN            Family              24
# ...

# %%
data['subscription_type'].value_counts()
# Out:
# subscription_type
# Free       6
# Family     6
# Student    4
# Premium    3
# Name: count, dtype: int64

# %%
data['subscription_type'].unique()
# Out:
# array(['Free', 'Family', 'Premium', 'Student'], dtype=object)

# %%
data['listening_time']=range(1,len(data)+1)

# %%
data['listening_time']=data['listening_time'].astype(float)

# %%
data
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# 12       13  Female   37      IN            Family              24
# ...

# %%
data['age'] = data['age'].astype(int).astype(float)
data['age'] = data['age'].fillna(data['age'].mean()).astype(int)

# %%
data
# Out:
#     user_id  gender  age country subscription_type  listening_time  \
# 0         1  Female   54      CA              Free              26
# 1         2   Other   33      DE            Family             141
# 2         3    Male   38      AU           Premium             199
# 3         4  Female   22      CA           Student              36
# 4         5   Other   29      US            Family             250
# 5         6  Female   17      AU              Free             219
# 6         7  Female   39      UK           Premium             289
# 7         8  Female   41      UK              Free             210
# 8         9   Other   55      DE           Student              50
# 9        10    Male   44      DE              Free             278
# 10       11   Other   33      DE              Free              86
# 11       12   Other   24      CA              Free             113
# 12       13  Female   37      IN            Family              24
# ...

# %%
# Visualize the distribution of HeartRate after imputation
plt.figure(figsize=(10, 6))
sns.histplot(data['subscription_type'], kde=True)
plt.xlabel('subscription_type')
plt.ylabel('listening_time')
plt.title('Distribution of Test_Result after Imputation')
plt.show()

# %%
sns.barplot(data=data, x="age",y="subscription_type")
# Out:
# <Axes: xlabel='age', ylabel='subscription_type'>

# %%
sns.lineplot(data=data, x="age", y="songs_played_per_day")
# Out:
# <Axes: xlabel='age', ylabel='songs_played_per_day'>

# %%
sns.boxenplot(data=data,x="user_id",y="subscription_type")
# Out:
# <Axes: xlabel='user_id', ylabel='subscription_type'>
